# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
from pprint import pprint

# %%
api_key = "F0060DD1-ABA0-3B8E-BD00-D08CAEE4F378"

url = "http://quickstats.nass.usda.gov/api/api_GET/?key=F0060DD1-ABA0-3B8E-BD00-D08CAEE4F378&commodity_desc=MILK&year__GE=2015&state_alpha=VA&format=JSON" 

response = requests.get(url).json()

pprint(response)
# Out:
# {'data': [{'CV (%)': '6.9',
#            'Value': '6,258,881',
#            'agg_level_desc': 'STATE',
#            'asd_code': '',
#            'asd_desc': '',
#            'begin_code': '00',
#            'class_desc': 'ALL CLASSES',
#            'commodity_desc': 'MILK',
#            'congr_district_code': '',
#            'country_code': '9000',
#            'country_name': 'UNITED STATES',
#            'county_ansi': '',
#            'county_code': '',
#            'county_name': '',
#            'domain_desc': 'ORGANIC STATUS',
#            'domaincat_desc': 'ORGANIC STATUS: (NOP USDA CERTIFIED)',
#            'end_code': '00',
#            'freq_desc': 'ANNUAL',
#            'group_desc': 'DAIRY',
#            'load_time': '2016-01-31 00:00:00',
#            'location_desc': 'VIRGINIA',
#            'prodn_practice_desc': 'ORGANIC',
#            'reference_period_desc': 'YEAR',
#            'region_desc': '',
#            'sector_desc': 'ANIMALS & PRODUCTS',
# ...

# %%
milk_data = response.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-bb57ad352137> in <module>
# ----> 1 milk_data = response.json()
#
# AttributeError: 'dict' object has no attribute 'json'
