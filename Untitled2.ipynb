# %%
import pandas as pd

# %%
data = pd.read_csv("20395AA3-4EE0-3D1D-A6E0-01E71AADCCA1.csv")

# %%
data
# Out:
#     Program  Year Period  Week Ending Geo Level           State  State ANSI  \
# 0    SURVEY  2017   YEAR          NaN     STATE         ALABAMA           1
# 1    SURVEY  2017   YEAR          NaN     STATE          ALASKA           2
# 2    SURVEY  2017   YEAR          NaN     STATE         ARIZONA           4
# 3    SURVEY  2017   YEAR          NaN     STATE        ARKANSAS           5
# 4    SURVEY  2017   YEAR          NaN     STATE      CALIFORNIA           6
# 5    SURVEY  2017   YEAR          NaN     STATE        COLORADO           8
# 6    SURVEY  2017   YEAR          NaN     STATE     CONNECTICUT           9
# 7    SURVEY  2017   YEAR          NaN     STATE        DELAWARE          10
# 8    SURVEY  2017   YEAR          NaN     STATE         FLORIDA          12
# 9    SURVEY  2017   YEAR          NaN     STATE         GEORGIA          13
# 10   SURVEY  2017   YEAR          NaN     STATE          HAWAII          15
# ...
